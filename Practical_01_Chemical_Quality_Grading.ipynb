# %% [markdown]
# # Practical 1: Chemical Product Quality Grading using Python
#
# ### Computer Programming Lab – Chemical Engineering
# **Topic:** Selection Statements (`if`, `elif`, `else`)
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: How we will use AI Copilot
#
# In this practical, GitHub Copilot is your **AI coding assistant**. You are expected to use it to understand concepts, get hints, debug your program and improve your solution.
#
# **Do not simply ask Copilot to write the complete practical.** First understand the problem, think about the conditions, and then use Copilot for assistance.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Use Python variables and user input.
# 2. Apply `if`, `elif` and `else` statements.
# 3. Use comparison operators such as `>`, `<`, `>=`, `<=` and `==`.
# 4. Combine conditions using logical operators such as `and` and `or`.
# 5. Apply selection statements to a chemical quality-control problem.
# 6. Test a program using normal, boundary and invalid input values.
# 7. Use GitHub Copilot to explain, debug and improve Python code.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# In a chemical manufacturing plant, a quality-control laboratory checks a product batch before it is released. Measurements such as **purity, pH and moisture content** are compared with predefined quality specifications.
#
# Based on these measurements, the batch may be classified as **Grade A, Grade B, Grade C**, or **Rejected**.
#
# In this practical, you will build a simple Python-based quality-check system for such a situation.

# %% [markdown]
# ## 3. Quality Specifications
#
# For this educational exercise, use the following specifications:
#
# | Parameter | Grade A | Grade B | Grade C | Reject |
# |---|---|---|---|---|
# | Purity | ≥ 98% | 95–97.99% | 90–94.99% | < 90% |
# | pH | 6.5–7.5 | 6.0–8.0 | 5.0–9.0 | Outside 5–9 |
# | Moisture | ≤ 1% | ≤ 2% | ≤ 4% | > 4% |
#
# **Important:** These values are created only for this practical. They are not specifications for a real chemical product.

# %% [markdown]
# ## 4. Activity 1 – Purity-based Classification
#
# ### Problem
#
# Write a Python program that accepts the purity percentage of a chemical product and classifies it as follows:
#
# - Purity ≥ 98 → Grade A
# - Purity ≥ 95 → Grade B
# - Purity ≥ 90 → Grade C
# - Otherwise → Rejected
#
# ### Before coding
#
# Think about the order of the conditions. Which condition should be checked first?

# %% [markdown]
# ### Copilot Activity 1 – Ask for an explanation
#
# Open GitHub Copilot Chat and use a prompt similar to:
#
# > I am a second-year chemical engineering student learning Python. Explain how if, elif and else can be used to classify a chemical product based on purity. Do not give me the complete program initially; explain the logic first.
#
# **Write one or two points here about what Copilot explained:**

# %% [markdown]
# ### Your Code – Activity 1
#
# Write your own program below. You may use Copilot for hints or explanations.

# %%
# Activity 1    
# Enter purity and classify the product.    
# Write your solution here. 
purity = float(input("Enter the purity of the product (as a percentage): ")) 
print (purity)
if purity >= 98.0:
    classification = "Grade A"
elif purity >= 95.0:
    classification = "Grade B"
elif purity >= 90.0:
    classification = "Grade C"
else:
    classification = "Rejected"
print(f"The product is classified as: {classification}")
# Out:
# 98.0
# The product is classified as: Grade A

# %% [markdown]
# ### Test your program
#
# Test at least these values:
#
# - 99.5
# - 96.0
# - 92.0
# - 85.0
# - 98.0  ← boundary value
#
# Record any surprising result and explain it.

# %% [markdown]
# ### Copilot Activity 3 – Logic Review
#
# After you have written your conditions, ask Copilot:
#
# > Review the logic of my chemical product quality classification program. Look for incorrect or overlapping conditions. Do not rewrite the whole program. Explain the problems and suggest what I should check.
#
# Use Copilot's feedback to improve your program.

# %% [markdown]
# ## 5. Activity 2 – Add pH Checking
#
# Now extend your program so that pH is also considered.
#
# For a batch to receive **Grade A**, both conditions must be satisfied:
#
# - Purity ≥ 98%
# - pH between 6.5 and 7.5
#
# If the purity is excellent but the pH is outside the Grade A range, the product must not be classified as Grade A.
#
# ### Think before coding
#
# What logical operator is required when **both conditions must be true**?

# %% [markdown]
# ### Copilot Activity 2 – Understand `and`
#
# Ask Copilot:
#
# > Explain the Python `and` operator using the example of checking whether the pH of a chemical batch is between 6.5 and 7.5. Give examples, but let me write the final code myself.
#
# Then modify your program to include pH.

# %%
# Activity 2
# Add pH as a quality parameter.
# Write/modify your solution here.
purity = float(input("Enter the purity of the product (as a percentage): ")) 
ph = float(input("Enter the pH of the product: "))
print (f"purity = {purity}, pH = {ph}")
if purity >= 98.0 and 6.5 <= ph <= 7.5:
    classification = "Grade A"
elif purity >= 95.0 and 6.0 <= ph <= 8.0:          
    classification = "Grade B"
elif purity >= 90.0 and 5.0 <= ph <= 9.0:
    classification = "Grade C"
else:
    classification = "Rejected"
print(f"The product is classified as: {classification}")
# Out:
# purity = 98.0, pH = 7.5
# The product is classified as: Grade A

# %% [markdown]
# ## 6. Activity 3 – Add Moisture Content
#
# Now include moisture content.
#
# For Grade A, all three conditions must be satisfied:
#
# 1. Purity ≥ 98%
# 2. pH between 6.5 and 7.5
# 3. Moisture ≤ 1%
#
# For this activity, create your own logical structure for determining the final grade.
#
# **Do not immediately ask Copilot for the complete answer. First draw or write the decision logic yourself.**

# %%
# Activity 3
# Complete chemical quality grading using:
# purity, pH and moisture.
# Write your solution here. 
purity = float(input("Enter the purity of the product (as a percentage): ")) 
ph = float(input("Enter the pH of the product: "))
moisture = float(input("Enter the moisture content of the product (as a percentage): "))
print (f"purity = {purity}, pH = {ph}, moisture = {moisture}")
if purity >= 98.0 and 6.5 <= ph <= 7.5 and moisture <= 1.0:
    classification = "Grade A"
elif purity >= 95.0 and 6.0 <= ph <= 8.0 and moisture <= 2.0:       
    classification = "Grade B"
elif purity >= 90.0 and 5.0 <= ph <= 9.0 and moisture <= 4.0:
    classification = "Grade C"
else:
    classification = "Rejected"
print(f"The product is classified as: {classification}")
# Out:
# purity = 98.0, pH = 7.5, moisture = 2.0
# The product is classified as: Grade B

# %% [markdown]
# ## 7. Activity 4 – Input Validation
#
# A real program should not accept obviously invalid measurements.
#
# For this exercise, use these basic checks:
#
# - Purity must be between 0 and 100.
# - pH must be between 0 and 14.
# - Moisture must not be negative.
#
# If an invalid value is entered, display an appropriate message instead of performing the quality grading.
#
# ### Copilot challenge
#
# Ask Copilot:
#
# > I need to validate purity, pH and moisture inputs in a beginner-level Python program. Explain a simple approach using if statements. Do not rewrite my entire program.

# %%
# Activity 4
# Add input validation to your quality-check program.   

purity = float(input("Enter the purity of the product (as a percentage): "))
ph = float(input("Enter the pH of the product: "))
moisture = float(input("Enter the moisture content of the product (as a percentage): "))

print (f"Entered purity = {purity}, pH = {ph}, moisture = {moisture}")

if purity < 0 or purity > 100 or ph < 0 or ph > 14 or moisture < 0 or moisture > 100:
    print("Invalid input. Please enter valid values for purity, pH, and moisture.")
else:
    if purity >= 98.0 and 6.5 <= ph <= 7.5 and moisture <= 1.0:
        classification = "Grade A"
    elif purity >= 95.0 and 6.0 <= ph <= 8.0 and moisture <= 2.0:
        classification = "Grade B"
    elif purity >= 90.0 and 5.0 <= ph <= 9.0 and moisture <= 4.0:
        classification = "Grade C"
    else:
        classification = "Rejected"
    print(f"The product is classified as: {classification}")
# Out:
# Entered purity = 98.0, pH = 7.5, moisture = 2.0
# The product is classified as: Grade B

# %% [markdown]
# ## 8. Activity 5 – Generate a Quality-Control Report
#
# Improve the output of your program so that it produces a simple QC report.
#
# Your output should contain:
#
# - Purity
# - pH
# - Moisture
# - Final Grade
# - Final Status
#
# For example:
#
# ```text
# ----------------------------------------
#        CHEMICAL QUALITY REPORT
# ----------------------------------------
# Purity       : 99.20 %
# pH           : 7.10
# Moisture     : 0.70 %
# Final Grade  : A
# Status       : APPROVED FOR RELEASE
# ----------------------------------------
# ```
#
# The exact design of your report may be different.

# %%
# Activity 5
# Improve the output and generate a simple QC report.

purity = float(input("Enter the purity of the product (as a percentage): "))
ph = float(input("Enter the pH of the product: "))
moisture = float(input("Enter the moisture content of the product (as a percentage): "))

if purity < 0 or purity > 100 or ph < 0 or ph > 14 or moisture < 0 or moisture > 100:
    print("\n----------------------------------------")
    print("         INVALID INPUT REPORT")
    print("----------------------------------------")
    print(f"Purity       : {purity:.2f} %")
    print(f"pH           : {ph:.2f}")
    print(f"Moisture     : {moisture:.2f} %")
    print("Status       : INVALID DATA")
    print("----------------------------------------")
else:
    if purity >= 98.0 and 6.5 <= ph <= 7.5 and moisture <= 1.0:
        grade = "A"
        status = "APPROVED FOR RELEASE"
    elif purity >= 95.0 and 6.0 <= ph <= 8.0 and moisture <= 2.0:
        grade = "B"
        status = "APPROVED FOR RELEASE"
    elif purity >= 90.0 and 5.0 <= ph <= 9.0 and moisture <= 4.0:
        grade = "C"
        status = "HOLD FOR REVIEW"
    else:
        grade = "REJECTED"
        status = "REJECTED"

    print("\n----------------------------------------")
    print("       CHEMICAL QUALITY REPORT")
    print("----------------------------------------")
    print(f"Purity       : {purity:.2f} %")
    print(f"pH           : {ph:.2f}")
    print(f"Moisture     : {moisture:.2f} %")
    print(f"Final Grade  : {grade}")
    print(f"Status       : {status}")
    print("----------------------------------------")
# Out:
# ----------------------------------------
#        CHEMICAL QUALITY REPORT
# ----------------------------------------
# Purity       : 98.00 %
# pH           : 7.50
# Moisture     : 2.00 %
# Final Grade  : B
# Status       : APPROVED FOR RELEASE
# ----------------------------------------

# %% [markdown]
# ## 9. Testing Your Program
#
# A program is not complete until it has been tested.
#
# Test the program using the following cases:
#
# | Test | Purity | pH | Moisture | What should be checked? |
# |---|---:|---:|---:|---|
# | 1 | 99.2 | 7.1 | 0.7 | Grade A |
# | 2 | 96.0 | 7.2 | 1.5 | Grade B |
# | 3 | 92.0 | 8.5 | 3.0 | Grade C |
# | 4 | 88.0 | 7.0 | 1.0 | Rejected |
# | 5 | 98.0 | 7.5 | 1.0 | Boundary condition |
# | 6 | 99.0 | 9.5 | 0.5 | pH condition |
# | 7 | 105.0 | 7.0 | 0.5 | Invalid purity |
# | 8 | 98.0 | -1.0 | 0.5 | Invalid pH |
# | 9 | 98.0 | 7.0 | -2.0 | Invalid moisture |
#
# **Important:** Do not assume your program is correct because one test worked. Check boundary and invalid cases too.

# %% [markdown]
# ## 10. Copilot Debugging Challenge
#
# The following program contains a logical problem. Study it before asking Copilot.
#
# ```python
# purity = float(input("Enter purity: "))
#
# if purity >= 90:
#     print("Grade C or better")
# elif purity >= 98:
#     print("Grade A")
# elif purity >= 95:
#     print("Grade B")
# else:
#     print("Rejected")
# ```
#
# ### Your task
#
# 1. Predict what happens when purity is `99`.
# 2. Run the code.
# 3. Identify why the result is not what you expected.
# 4. Ask Copilot to **explain the logical error**, rather than asking it to rewrite the program.
# 5. Correct the problem yourself.

# %%
# Run the intentionally incorrect program here.
purity = float(input("Enter purity: "))

if purity >= 98:
    print("Grade A")
elif purity >= 95:
    print("Grade B")
elif purity >= 90:
    print("Grade C")
else:
    print("Rejected")
# Out:
# Rejected

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before moving on.

# %% [markdown]
# ## 11. Final Copilot Challenge
#
# Ask Copilot to generate **three additional test cases** for your completed program.
#
# Use this prompt:
#
# > My Python program classifies chemical batches using purity, pH and moisture. Suggest three useful test cases, including at least one boundary case. Do not change my program.
#
# Run the suggested cases and decide whether your program behaves correctly.

# %% [markdown]
# ## 12. Final Program
#
# Combine your work into one clean final program.
#
# Your final program should:
#
# 1. Accept purity, pH and moisture.
# 2. Validate the input values.
# 3. Classify the chemical batch.
# 4. Display a readable QC report.
# 5. Work correctly for the provided test cases.
#
# **Before submitting, remove unnecessary code and comments generated during experimentation.**

# %%
# Final Program
purity = float(input("Enter the purity of the product (as a percentage): "))
ph = float(input("Enter the pH of the product: "))
moisture = float(input("Enter the moisture content of the product (as a percentage): "))

if purity < 0 or purity > 100 or ph < 0 or ph > 14 or moisture < 0:
    print("\n----------------------------------------")
    print("       INVALID INPUT REPORT")
    print("----------------------------------------")
    print(f"Purity       : {purity:.2f} %")
    print(f"pH           : {ph:.2f}")
    print(f"Moisture     : {moisture:.2f} %")
    print("Status       : INVALID DATA")
    print("----------------------------------------")
else:
    if purity >= 98.0 and 6.5 <= ph <= 7.5 and moisture <= 1.0:
        grade = "A"
        status = "APPROVED FOR RELEASE"
    elif purity >= 95.0 and 6.0 <= ph <= 8.0 and moisture <= 2.0:
        grade = "B"
        status = "APPROVED FOR RELEASE"
    elif purity >= 90.0 and 5.0 <= ph <= 9.0 and moisture <= 4.0:
        grade = "C"
        status = "HOLD FOR REVIEW"
    else:
        grade = "REJECTED"
        status = "REJECTED"

    print("\n----------------------------------------")
    print("       CHEMICAL QUALITY REPORT")
    print("----------------------------------------")
    print(f"Purity       : {purity:.2f} %")
    print(f"pH           : {ph:.2f}")
    print(f"Moisture     : {moisture:.2f} %")
    print(f"Final Grade  : {grade}")
    print(f"Status       : {status}")
    print("----------------------------------------")

# %% [markdown]
# ## 13. Reflection – What Did You Learn?
#
# Answer these questions in your own words.
#
# 1. Why is the order of `if` and `elif` conditions important?
# 2. What is the difference between `and` and `or`?
# 3. What happens when a value is exactly on a boundary such as purity = 98?
# 4. Why is input validation important in a quality-control program?
# 5. Which part of your program did Copilot help you with?
# 6. What error did Copilot help you find or understand?
# 7. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 14. Submission Checklist
#
# Before submitting, confirm:
#
# - [ ] I completed all activities.
# - [ ] My final program accepts purity, pH and moisture.
# - [ ] My program validates invalid inputs.
# - [ ] I tested normal values.
# - [ ] I tested boundary values.
# - [ ] I tested invalid values.
# - [ ] I used Copilot for explanation/debugging, not just for copying a complete solution.
# - [ ] I can explain the logic of my final program.
# - [ ] I saved the notebook in my GitHub repository.

# %% [markdown]
# ## Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Basic input and variables | 1 |
# | Correct use of `if` / `elif` / `else` | 2 |
# | Correct chemical quality logic | 2 |
# | Input validation | 1 |
# | Testing and boundary cases | 1 |
# | QC report/output | 1 |
# | Copilot usage and explanation | 1 |
# | Student's ability to explain the program | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, ask the student to modify one condition or explain one line of code. This helps distinguish genuine understanding from direct AI-generated solutions.
