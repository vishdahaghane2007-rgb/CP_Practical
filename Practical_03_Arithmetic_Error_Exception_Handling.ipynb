# %% [markdown]
# # Practical 3: Chemical Measurement Calculator using Python
#
# ### Computer Programming Lab – Chemical Engineering
# **Topic:** Arithmetic Operations with Error and Exception Handling
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: How we will use AI Copilot
#
# In this practical, GitHub Copilot is your **AI coding assistant**. Use it to understand Python arithmetic, identify possible errors, handle exceptions and improve your program.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand the chemical calculation and predict what can go wrong. Then use Copilot for explanations, hints and debugging.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Use Python variables and user input for numerical data.
# 2. Perform addition, subtraction, multiplication, division and modulus operations.
# 3. Work with floating-point values used in chemical measurements.
# 4. Understand why floating-point calculations can produce small numerical differences.
# 5. Use `try` and `except` to handle common input and calculation errors.
# 6. Handle invalid numerical input and division-by-zero situations.
# 7. Apply arithmetic operations to simple chemical-engineering calculations.
# 8. Use GitHub Copilot to explain, debug and improve error-handling code.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# Arithmetic calculations are performed continuously in chemical laboratories and process plants. Engineers may need to combine measured quantities, calculate rates and concentrations, convert units, compare measurements and determine remaining quantities.
#
# In this practical, you will build a small **Chemical Measurement Calculator**. The calculator will begin with simple arithmetic and gradually become safer by handling invalid input and calculation errors.
#
# **Important:** The numerical values used in this practical are educational examples. Always use actual process specifications and laboratory procedures for real engineering work.

# %% [markdown]
# ## 3. Activity 1 – Basic Arithmetic with Chemical Measurements
#
# Suppose a laboratory records two mass measurements of a chemical sample:
#
# - Measurement 1 = `125.50 g`
# - Measurement 2 = `74.25 g`
#
# Use Python to calculate:
#
# 1. Total mass using `+`
# 2. Difference using `-`
# 3. Product using `*`
# 4. Ratio using `/`
# 5. Remainder using `%`
#
# ### Think before coding
#
# What does each arithmetic operation mean mathematically? Which operations have a useful interpretation for this example, and which are included mainly to learn Python arithmetic?

# %% [markdown]
# ### Copilot Activity 1 – Understand Arithmetic Operators
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student learning Python. Explain +, -, *, / and % using two chemical measurement values as examples. Explain the meaning of each operator, but do not write the complete program.
#
# Write two important points you learned from Copilot.

# %%
# Activity 1
# Use two chemical measurement values and perform +, -, *, / and %.
measurement1 = 10.5  # Example chemical measurement value 1
measurement2 = 3.2   # Example chemical measurement value 2

# Perform arithmetic operations
addition = measurement1 + measurement2
subtraction = measurement1 - measurement2
multiplication = measurement1 * measurement2
division = measurement1 / measurement2
# modulus = measurement1 % measurement2 
modulus = measurement1 % measurement2  

# Print the results
print(f"Addition: {measurement1} + {measurement2} = {addition}")
print(f"Subtraction: {measurement1} - {measurement2} = {subtraction}")
print(f"Multiplication: {measurement1} * {measurement2} = {multiplication}")
print(f"Division: {measurement1} / {measurement2} = {division}")
print(f"Modulus: {measurement1} % {measurement2} = {modulus}")
# Out:
# Addition: 10.5 + 3.2 = 13.7
# Subtraction: 10.5 - 3.2 = 7.3
# Multiplication: 10.5 * 3.2 = 33.6
# Division: 10.5 / 3.2 = 3.28125
# Modulus: 10.5 % 3.2 = 0.8999999999999995

# %%
x = 9 // 2
y = 9 % 2 
z = 9 / 2
print(x, y, z)
# Out:
# 4 1 4.5

# %% [markdown]
# ## 4. Activity 2 – User Input
#
# Modify your program so that the user enters the two measurement values instead of using fixed values.
#
# For example:
#
# ```text
# Enter first mass (g): 125.50
# Enter second mass (g): 74.25
# ```
#
# The program should then display the arithmetic results.
#
# ### Important Python concept
#
# Remember that `input()` returns text. If you need decimal calculations, the input must be converted appropriately.

# %% [markdown]
# ### Copilot Activity 2 – Input Conversion
#
# Ask Copilot:
#
# > Explain why input() normally needs to be converted using float() when I want to perform decimal arithmetic in Python. Use a chemical measurement example. Do not give me the complete program.

# %%
# Activity 2
# Accept two decimal measurement values from the user.
# Perform the five arithmetic operations.

measurement1 = float(input("Enter the first chemical measurement value: "))
measurement2 = float(input("Enter the second chemical measurement value: "))

print("Measurement1:", measurement1)
print("Measurement2:", measurement2)

# Perform arithmetic operations
addition = measurement1 + measurement2
subtraction = measurement1 - measurement2
multiplication = measurement1 * measurement2
division = measurement1 / measurement2
# Modulus = measurement1 % measurement2
modulus = measurement1 % measurement2

# Print the results
print(f"Addition: {measurement1} + {measurement2} = {addition}")
print(f"Subtraction: {measurement1} - {measurement2} = {subtraction}")
print(f"Multiplication: {measurement1} * {measurement2} = {multiplication}")
print(f"Division: {measurement1} / {measurement2} = {division}")
print(f"Modulus: {measurement1} % {measurement2} = {modulus}")
# Out:
# Measurement1: 99.0
# Measurement2: 565.0
# Addition: 99.0 + 565.0 = 664.0
# Subtraction: 99.0 - 565.0 = -466.0
# Multiplication: 99.0 * 565.0 = 55935.0
# Division: 99.0 / 565.0 = 0.1752212389380531
# Modulus: 99.0 % 565.0 = 99.0

# %% [markdown]
# ## 5. Activity 3 – Chemical Concentration Calculation
#
# A simple laboratory calculation of concentration by mass/volume can be represented as:
#
# ```text
# Concentration = mass / volume
# ```
#
# Suppose:
#
# - Solute mass = `25.50 g`
# - Solution volume = `500.00 mL`
#
# Calculate the concentration in `g/mL`.
#
# Then modify your program so that the user enters the mass and volume.

# %% [markdown]
# ### Copilot Activity 3 – Engineering Calculation
#
# Ask Copilot:
#
# > I need to calculate concentration as mass divided by volume in a beginner Python program. Explain how I should structure the calculation and what input problem I should consider before performing the division. Do not write the complete program.

# %%
# Activity 3
# Calculate density from user-entered mass and volume.
mass = float(input("Enter the mass of the substance (in grams): "))
volume = float(input("Enter the volume of the substance (in liters): "))

print("Mass:", mass)
print("Volume:", volume)

# Calculate density (density = mass / volume)
density = mass / volume

# Print the density
print(f"The density of the substance is: {density} g/L")
# Out:
# Mass: 88.0
# Volume: 98.0
# The density of the substance is: 0.8979591836734694 g/L

# %% [markdown]
# ## 6. Activity 4 – Floating-Point Accuracy
#
# Python uses floating-point representation for many decimal values. Because of the way computers store binary floating-point numbers, some apparently simple decimal calculations can produce a very small representation difference.
#
# Run the following expressions:
#
# ```python
# print(0.1 + 0.2)
# print(0.1 + 0.2 == 0.3)
# ```
#
# Observe the result.
#
# This does **not** mean Python cannot perform decimal calculations. It means that binary floating-point representation can introduce very small rounding differences.

# %% [markdown]
# ### Copilot Activity 4 – Understand Floating-Point Representation
#
# Ask Copilot:
#
# > Explain why Python can display a result such as 0.30000000000000004 when calculating 0.1 + 0.2. Explain it to a second-year engineering student without using advanced computer-science terminology.

# %%
# Activity 4
# Experiment with floating-point calculations.
# Try several decimal values used in laboratory measurements.

print(0.1 + 0.2)  # Example of floating-point addition
print(0.1 + 0.2 == 0.3)  # Check if the result is exactly equal to 0.3
# Out:
# 0.30000000000000004
# False

# %% [markdown]
# ## 7. Activity 5 – Rounding Chemical Measurements
#
# Laboratory results are often reported with an appropriate number of decimal places.
#
# Use Python's `round()` function to display a calculated concentration to:
#
# - 2 decimal places
# - 3 decimal places
# - 4 decimal places
#
# For example, compare the raw calculation with its rounded display.
#
# **Important:** Rounding the displayed value does not necessarily mean that the original stored value has been changed.

# %%
# Activity 5
# Calculate a chemical measurement and display it with different precisions.
measurement = 10.123456789  # Example chemical measurement value 
print(f"Measurement: {measurement}")
print(f"Measurement (2 decimal places): {measurement:.2f}")
print(f"Measurement (4 decimal places): {measurement:.4f}")
print(f"Measurement (6 decimal places): {measurement:.6f}")

m2 = round(measurement, 2)
print(f"Measurement (rounded to 2 decimal places): {m2}")   

m3 = round(measurement, 3)
print(f"Measurement (rounded to 3 decimal places): {m3}")

m4 = round(measurement, 4)
print(f"Measurement (rounded to 4 decimal places): {m4}")
# Out:
# Measurement: 10.123456789
# Measurement (2 decimal places): 10.12
# Measurement (4 decimal places): 10.1235
# Measurement (6 decimal places): 10.123457
# Measurement (rounded to 2 decimal places): 10.12
# Measurement (rounded to 3 decimal places): 10.123
# Measurement (rounded to 4 decimal places): 10.1235

# %% [markdown]
# ## 8. Activity 6 – Handle Invalid Numerical Input
#
# What happens if the user enters:
#
# ```text
# Enter mass: twenty five
# ```
#
# The conversion using `float()` will fail.
#
# Your program should not simply crash. It should display a useful message such as:
#
# ```text
# Invalid input. Please enter a numerical value.
# ```
#
# Use `try` and `except` to handle this situation.

# %% [markdown]
# ### Copilot Activity 5 – Understand `try` / `except`
#
# Ask Copilot:
#
# > Explain try and except in Python using a chemical laboratory measurement input example. Explain what ValueError means when converting user input to float. Do not write my complete program.

# %%
measurement1 = input("Enter the first chemical measurement value: ")
measurement2 = input("Enter the second chemical measurement value: ")

print("Measurement1:", measurement1, type(measurement1))
print("Measurement2:", measurement2, type(measurement2))

# Convert the input values to float for arithmetic operations
measurement1 = float(measurement1)
measurement2 = float(measurement2)

# Perform arithmetic operations
addition = measurement1 + measurement2
subtraction = measurement1 - measurement2
multiplication = measurement1 * measurement2
division = measurement1 / measurement2
# Modulus = measurement1 % measurement2
modulus = measurement1 % measurement2

# Print the results
print(f"Addition: {measurement1} + {measurement2} = {addition}")
print(f"Subtraction: {measurement1} - {measurement2} = {subtraction}")
print(f"Multiplication: {measurement1} * {measurement2} = {multiplication}")
print(f"Division: {measurement1} / {measurement2} = {division}")
print(f"Modulus: {measurement1} % {measurement2} = {modulus}")
# Out:
# Measurement1: 10 <class 'str'>
# Measurement2: twenty <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 9
#       7 # Convert the input values to float for arithmetic operations
#       8 measurement1 = float(measurement1)
# ----> 9 measurement2 = float(measurement2)
#      11 # Perform arithmetic operations
#      12 addition = measurement1 + measurement2
#
# ValueError: could not convert string to float: 'twenty'

# %%
# Activity 6
# Add try/except to safely handle non-numerical user input.
measurement1 = input("Enter the first chemical measurement value: ")
measurement2 = input("Enter the second chemical measurement value: ")

print("Measurement1:", measurement1, type(measurement1))
print("Measurement2:", measurement2, type(measurement2))

try:
    # Convert the input values to float for arithmetic operations
    measurement1 = float(measurement1)
    measurement2 = float(measurement2)

    # Perform arithmetic operations
    addition = measurement1 + measurement2
    subtraction = measurement1 - measurement2
    multiplication = measurement1 * measurement2
    division = measurement1 / measurement2
    # Modulus = measurement1 % measurement2
    modulus = measurement1 % measurement2

    # Print the results
    print(f"Addition: {measurement1} + {measurement2} = {addition}")
    print(f"Subtraction: {measurement1} - {measurement2} = {subtraction}")
    print(f"Multiplication: {measurement1} * {measurement2} = {multiplication}")
    print(f"Division: {measurement1} / {measurement2} = {division}")
    print(f"Modulus: {measurement1} % {measurement2} = {modulus}")
except ValueError:
    print("Error: Please enter valid numerical values for the measurements.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed. Please enter a non-zero value for the second measurement.")
# Out:
# Measurement1: 120 <class 'str'>
# Measurement2: 0 <class 'str'>
# Error: Division by zero is not allowed. Please enter a non-zero value for the second measurement.

# %% [markdown]
# ## 9. Activity 7 – Handle Division by Zero
#
# Return to the concentration calculation:
#
# ```text
# Concentration = mass / volume
# ```
#
# What happens if the user enters:
#
# ```text
# Volume = 0
# ```
#
# Python cannot perform division by zero.
#
# Modify your program so that the error is handled safely and the user receives a meaningful message.

# %% [markdown]
# ### Copilot Activity 6 – Debugging and Exception Handling
#
# Ask Copilot:
#
# > My Python program calculates concentration as mass/volume. What exception can occur if volume is zero, and how can I handle it safely? Explain the approach without rewriting my complete program.

# %%
# Activity 7
# Handle division by zero in the concentration calculation.
try:
    mass = float(input("Enter the mass of the substance (in grams): "))
    volume = float(input("Enter the volume of the substance (in liters): "))

    print("Mass:", mass)
    print("Volume:", volume)

    # Calculate density (density = mass / volume)
    density = mass / volume

    # Print the density
    print(f"The density of the substance is: {density} g/L")
except ValueError:
    print("Error: Please enter valid numerical values for mass and volume.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed. Please enter a non-zero value for volume.")
# Out:
# Mass: 66.0
# Volume: 55.0
# The density of the substance is: 1.2 g/L

# %% [markdown]
# ## 10. Activity 8 – Build a Safe Chemical Arithmetic Calculator
#
# Now combine the concepts into a small calculator.
#
# The user should be able to enter two numerical values and select an operation:
#
# ```text
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# ```
#
# The program should:
#
# 1. Accept numerical input.
# 2. Accept the operation choice.
# 3. Perform the selected arithmetic operation.
# 4. Handle non-numerical input.
# 5. Handle division/modulus by zero.
# 6. Display the result with suitable decimal precision.

# %% [markdown]
# ### Copilot Activity 7 – Program Design Review
#
# Before coding, ask Copilot:
#
# > I am designing a beginner Python chemical arithmetic calculator with five operations and exception handling. Suggest a simple program structure using input, if/elif/else, try/except and arithmetic operators. Do not write the complete program.
#
# Draw or write your own program structure first, then implement it.

# %%
# Activity 8
# Build your safe chemical arithmetic calculator.
# Chemical arithmetic calculator

try:
    num1 = float(input("Enter the first value: "))
    num2 = float(input("Enter the second value: "))

    print("Choose an operation:")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")

    choice = input("Enter your choice (1-5): ")

    if choice == "1":
        result = num1 + num2
        print(f"Result: {num1} + {num2} = {result}")
    elif choice == "2":
        result = num1 - num2
        print(f"Result: {num1} - {num2} = {result}")
    elif choice == "3":
        result = num1 * num2
        print(f"Result: {num1} * {num2} = {result}")
    elif choice == "4":
        if num2 == 0:
            print("Error: Division by zero is not allowed.")
        else:
            result = num1 / num2
            print(f"Result: {num1} / {num2} = {result}")
    elif choice == "5":
        if num2 == 0:
            print("Error: Modulus by zero is not allowed.")
        else:
            result = num1 % num2
            print(f"Result: {num1} % {num2} = {result}")
    else:
        print("Invalid operation choice. Please enter a number from 1 to 5.")

except ValueError:
    print("Error: Please enter valid numeric values.")
# Out:
# Choose an operation:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# Result: 2.0 + 5.0 = 7.0

# %% [markdown]
# ## 11. Copilot Debugging Challenge
#
# The following program contains an exception-handling problem.
#
# Study it before asking Copilot.
#
# ```python
# try:
#     mass = float(input("Enter mass (g): "))
#     volume = float(input("Enter volume (mL): "))
#     concentration = mass / volume
#     print("Concentration:", concentration)
# except ValueError:
#     print("Please enter numerical values.")
# ```
#
# ### Your task
#
# 1. Run the program with `mass = 25` and `volume = 0`.
# 2. Observe what happens.
# 3. Identify why the existing `except` block does not handle this situation.
# 4. Ask Copilot:
#
# > My try/except handles invalid numeric input, but the concentration program still crashes when volume is zero. Explain which exception is missing and why.
#
# 5. Correct the program yourself.

# %%
# Run the intentionally incomplete exception-handling program here.
try:
    mass = float(input("Enter mass (g): "))
    volume = float(input("Enter volume (mL): "))
    concentration = mass / volume
    print("Concentration:", concentration)
except ValueError:
    print("Please enter numerical values.")

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 12. Testing Your Calculator
#
# A good program should be tested with normal, boundary and invalid inputs.
#
# | Test | First value | Second value | Operation | Expected situation |
# |---|---:|---:|---|---|
# | 1 | 25.50 | 10.00 | Addition | Normal calculation |
# | 2 | 25.50 | 10.00 | Subtraction | Normal calculation |
# | 3 | 25.50 | 10.00 | Multiplication | Normal calculation |
# | 4 | 25.50 | 10.00 | Division | Normal calculation |
# | 5 | 25.50 | 10.00 | Modulus | Normal calculation |
# | 6 | 25.50 | 0 | Division | Division-by-zero handling |
# | 7 | 25.50 | 0 | Modulus | Modulus-by-zero handling |
# | 8 | `abc` | 10.00 | Addition | Invalid input handling |
# | 9 | 0.1 | 0.2 | Addition | Floating-point observation |
# | 10 | 25.50 | 500 | Concentration | Chemical calculation |

# %% [markdown]
# ## 13. Final Mini-Project – Chemical Laboratory Arithmetic & Measurement Calculator
#
# Combine your work into one clean beginner-friendly program.
#
# Your final program should provide a simple menu such as:
#
# ```text
# CHEMICAL LABORATORY CALCULATOR
# 1. Add two measurements
# 2. Subtract two measurements
# 3. Multiply two measurements
# 4. Divide two measurements
# 5. Find remainder
# 6. Calculate concentration (mass/volume)
# ```
#
# The program should:
#
# 1. Accept numerical values from the user.
# 2. Perform the selected calculation.
# 3. Handle invalid numerical input using exception handling.
# 4. Handle division or modulus by zero safely.
# 5. Display numerical results with suitable precision.
# 6. Give clear and useful error messages.
#
# **Keep the program simple. Do not add advanced libraries or programming techniques that have not been discussed in class.**

# %%
# FINAL PROGRAM
# Chemical Laboratory Arithmetic & Measurement Calculator
# Write your clean final solution here.

# %% [markdown]
# ## 14. Final Copilot Review
#
# After completing your final program, ask Copilot:
#
# > Review my Python chemical laboratory calculator for arithmetic and exception-handling problems. Check whether invalid numerical input, division by zero and modulus by zero are handled correctly. Also check whether my floating-point results are displayed appropriately. Do not rewrite my program; identify possible issues and explain them.
#
# Make corrections only after you understand the feedback.

# %% [markdown]
# ## 15. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. What is the difference between `/` and `%` in Python?
# 2. Why is `float()` useful for chemical measurements?
# 3. Why can `0.1 + 0.2` produce a result that appears slightly different from `0.3`?
# 4. What does `try` do in Python?
# 5. What is the purpose of `except`?
# 6. What exception can occur when text such as `abc` is converted using `float()`?
# 7. What exception can occur when a number is divided by zero?
# 8. Why should a laboratory calculator provide a useful error message instead of simply crashing?
# 9. What did Copilot help you understand or debug?
# 10. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 16. Submission Checklist
#
# - [ ] I completed all activities.
# - [ ] I used addition, subtraction, multiplication, division and modulus.
# - [ ] I used decimal/floating-point values.
# - [ ] I investigated floating-point precision.
# - [ ] I used `round()` appropriately for displayed results.
# - [ ] I handled invalid numerical input.
# - [ ] I handled division by zero.
# - [ ] I handled modulus by zero.
# - [ ] I tested normal, boundary and invalid cases.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 17. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Variables, input and basic arithmetic | 2 |
# | Correct arithmetic operations | 2 |
# | Chemical concentration calculation | 1 |
# | Floating-point accuracy / rounding | 1 |
# | Exception handling | 2 |
# | Testing and error messages | 1 |
# | Copilot usage and explanation | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, deliberately enter text instead of a number or enter zero as the divisor. Ask the student to explain which exception is expected and why. You can also ask why floating-point results sometimes require controlled display precision.
