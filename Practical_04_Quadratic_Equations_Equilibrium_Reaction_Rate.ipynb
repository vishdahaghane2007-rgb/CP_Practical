# %% [markdown]
# # Practical 4: Solving Quadratic Equations for Equilibrium and Reaction Rate Expressions
#
# ### Computer Programming Lab – Chemical Engineering
# **Topic:** Solving roots of quadratic equations relevant to equilibrium and reaction rate expressions
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: How we will use AI Copilot
#
# In this practical, GitHub Copilot is your **AI coding assistant**. Use it to understand the chemical equation, identify the quadratic form, write Python expressions, check your logic and debug your program.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand the chemistry and derive the equation. Then use Copilot for hints, explanations and debugging.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Identify a quadratic equation arising from a simplified chemical-engineering expression.
# 2. Calculate the coefficients `a`, `b` and `c`.
# 3. Calculate and interpret the discriminant.
# 4. Solve for the roots using Python.
# 5. Handle two real roots, repeated roots and complex roots appropriately.
# 6. Apply quadratic equations to a simplified **chemical equilibrium** problem.
# 7. Understand how a quadratic relationship can also arise from a **reaction-rate expression**.
# 8. Apply physical constraints to select a chemically meaningful root.
# 9. Use GitHub Copilot to explain, debug and improve the solution.

# %% [markdown]
# ## 2. Why Quadratic Equations Matter in Chemical Engineering
#
# Quadratic equations are not being introduced here as an isolated mathematics exercise. They can arise when chemical-engineering relationships are rearranged to determine an unknown concentration, extent of reaction, or process variable.
#
# In this practical we will use two contexts:
#
# ### Context A – Chemical Equilibrium
# A simplified equilibrium relationship can lead to a quadratic equation in the **extent of reaction** `x`.
#
# ### Context B – Reaction Rate Expression
# A rate expression containing a squared concentration can also be rearranged into a quadratic equation when the unknown concentration must be determined.
#
# The objective is to teach students how to move through the complete chain:
#
# **Chemical expression → algebraic equation → quadratic coefficients → Python calculation → roots → physical interpretation**
#
# **Important:** The examples below are deliberately simplified for programming practice. They are not intended to replace a complete chemical-equilibrium or reaction-engineering analysis.

# %% [markdown]
# ## 3. The Quadratic Formula
#
# genui{"algebra_expressions_equations_learning_block":{"type_id":"QUADRATIC_FORMULA"}}
#
# For an equation of the form:
#
# ```text
# a x² + b x + c = 0
# ```
#
# the roots are obtained from the quadratic formula.
#
# The discriminant is:
#
# ```text
# Δ = b² - 4ac
# ```
#
# The discriminant tells us the nature of the mathematical roots:
#
# | Discriminant | Roots |
# |---|---|
# | Δ > 0 | Two distinct real roots |
# | Δ = 0 | One repeated real root |
# | Δ < 0 | Two complex roots |
#
# However, in chemical engineering **mathematical validity is not enough**. A root must also satisfy physical restrictions such as concentration ≥ 0 or extent of reaction lying within the allowable range.

# %% [markdown]
# ## 4. Activity 1 – Warm-up with a Simple Quadratic
#
# Consider:
#
# ```text
# 2x² - 7x + 3 = 0
# ```
#
# Identify:
#
# - `a`
# - `b`
# - `c`
#
# Then calculate the discriminant manually and predict the number of real roots.
#
# ### Think before coding
#
# Why is it useful to know the discriminant **before** calculating the square root?

# %% [markdown]
# ### Copilot Activity 1 – Understand the Discriminant
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student learning Python. Explain how the discriminant tells me whether a quadratic equation has two real roots, one repeated root or complex roots. Do not write the complete Python program.

# %%
# Activity 1
# Store a, b and c and calculate the discriminant.
a = 2
b = -7
c = 3
discriminant = b**2 - 4*a*c     
print("Discriminant:", discriminant)
# Out:
# Discriminant: 25

# %% [markdown]
# ## 5. Activity 2 – Chemical Equilibrium Problem
#
# Consider the simplified equilibrium reaction:
#
# ```text
# A + B ⇌ C
# ```
#
# Assume initially:
#
# - `[A]₀ = 1.0 mol/L`
# - `[B]₀ = 1.0 mol/L`
# - `[C]₀ = 0 mol/L`
#
# Let `x` be the equilibrium concentration formed of C.
#
# At equilibrium:
#
# ```text
# [A] = 1 - x
# [B] = 1 - x
# [C] = x
# ```
#
# For this simplified example, take:
#
# ```text
# Kc = [C] / ([A][B])
# ```
#
# Therefore:
#
# ```text
# Kc = x / (1 - x)²
# ```
#
# Rearranging gives:
#
# ```text
# Kc x² - (2Kc + 1)x + Kc = 0
# ```
#
# **This is the key chemical-engineering connection of this practical:** the equilibrium expression has been converted into a quadratic equation in `x`.

# %% [markdown]
# ### Copilot Activity 2 – Understand the Equilibrium Derivation
#
# Ask Copilot:
#
# > I am studying the simplified equilibrium A + B ⇌ C with initial concentrations A=1, B=1, C=0. If x is the equilibrium concentration of C, explain step-by-step how Kc = x/((1-x)(1-x)) can be rearranged into Kc*x² - (2*Kc+1)*x + Kc = 0. Do not write Python code.
#
# After reading the explanation, write the derivation in your own words.

# %% [markdown]
# ## 6. Activity 3 – Solve the Equilibrium Quadratic
#
# Use:
#
# ```text
# Kc = 4
# ```
#
# For the derived equation:
#
# ```text
# Kc x² - (2Kc + 1)x + Kc = 0
# ```
#
# calculate the values of:
#
# - `a`
# - `b`
# - `c`
#
# Then solve for both mathematical roots.
#
# ### Engineering question
#
# Since `x` represents the concentration formed at equilibrium, which mathematical root is physically meaningful? Explain why.

# %% [markdown]
# ### Copilot Activity 3 – Physical Root Selection
#
# Ask Copilot:
#
# > In a chemical-equilibrium calculation, x represents an equilibrium concentration formed from an initial concentration of 1 mol/L. Explain what physical restrictions should be considered when choosing between mathematical roots. Do not solve the specific equation for me.

# %%
# Activity 3
# For Kc = 4, calculate the quadratic coefficients and solve for x.
# Identify the physically meaningful root.

kc = 4
a = kc
b = -(2*kc + 1)
c = kc 

determinant = b**2 - 4*a*c
print("Determinant:", determinant)
if determinant < 0:
    print("No real roots.")
else:
    root1 = (-b + determinant**0.5) / (2*a)
    root2 = (-b - determinant**0.5) / (2*a)
    print("Roots:", root1, root2)
# Out:
# Determinant: 17
# Roots: 1.6403882032022077 0.6096117967977924

# %% [markdown]
# ## 7. Activity 4 – Build a General Equilibrium Solver
#
# Now convert the previous calculation into a reusable Python program.
#
# The user should enter `Kc`.
#
# The program should:
#
# 1. Calculate `a = Kc`.
# 2. Calculate `b = -(2Kc + 1)`.
# 3. Calculate `c = Kc`.
# 4. Calculate the discriminant.
# 5. Calculate the two roots.
# 6. Identify which root satisfies the physical condition `0 ≤ x ≤ 1`.
# 7. Calculate the equilibrium concentrations of A, B and C.

# %% [markdown]
# ### Copilot Activity 4 – Program Structure
#
# Ask Copilot:
#
# > Help me design a beginner Python program that accepts Kc, creates the quadratic coefficients for the simplified equilibrium A + B ⇌ C, solves the quadratic equation, and checks which root lies between 0 and 1. Explain the program structure without writing the complete solution.

# %%
# Activity 4
# Build the general equilibrium solver.

kc = int(input("Enter the value of Kc: "))
print(f"Kc = {kc}")
a = kc
b = -(2*kc + 1)
c = kc      

determinant = b**2 - 4*a*c
print(f"Determinant: {determinant}")  

if determinant < 0:
    print("No real roots.")
else:   
    root1 = (-b + determinant**0.5) / (2*a)
    root2 = (-b - determinant**0.5) / (2*a)
    print(f"Roots: {root1 :.4f}, {root2 :.4f}")  

    if  0 <= root1 < 1.0:
        print(f"Physically meaningful root: {root1 :.4f}") 
        root = root1
    elif 0 <= root2 < 1.0:
        print(f"Physically meaningful root: {root2 :.4f}") 
        root = root2  

        A = 1 - root
        B = 1 - root
        C = root
        print(f"Equilibrium concentrations: A = {A :.4f}, B = {B :.4f}, C = {C :.4f}")
# Out:
# Kc = 5
# Determinant: 21
# Roots: 1.5583, 0.6417
# Physically meaningful root: 0.6417
# Equilibrium concentrations: A = 0.3583, B = 0.3583, C = 0.6417

# %% [markdown]
# ## 8. Activity 5 – Reaction Rate Expression
#
# Now consider a simplified reaction-rate relationship:
#
# ```text
# r = kC²
# ```
#
# Suppose the rate `r` and rate constant `k` are known, but the concentration `C` is unknown.
#
# Rearrange:
#
# ```text
# kC² - r = 0
# ```
#
# This is a quadratic equation in `C` with:
#
# ```text
# a = k
# b = 0
# c = -r
# ```
#
# The mathematical roots will include a positive and a negative value when `k > 0` and `r > 0`.
#
# ### Engineering interpretation
#
# If `C` represents concentration, which root should normally be selected? Why?

# %% [markdown]
# ### Copilot Activity 5 – Reaction Rate Interpretation
#
# Ask Copilot:
#
# > Explain how the rate expression r = kC² can be rearranged into a quadratic equation in C, and why only one of the mathematical roots is physically meaningful when C represents concentration. Do not write the Python code.

# %%
# Activity 5
# Given k and r, solve kC² - r = 0 using the quadratic formula.
# Identify the physically meaningful concentration.

k = 5
r = 10  
a = k
b = 0
c = -r  

determinant = b**2 - 4*a*c
print("Determinant:", determinant)
if determinant < 0:
    print("No real roots.")
else:
    root1 = (-b + determinant**0.5) / (2*a)
    root2 = (-b - determinant**0.5) / (2*a)
    print("Roots:", root1, root2)
# Out:
# Determinant: 200
# Roots: 1.4142135623730951 -1.4142135623730951

# %% [markdown]
# ## 9. Activity 6 – General Reaction Rate Calculator
#
# Build a small program that accepts:
#
# - rate constant `k`
# - reaction rate `r`
#
# and calculates the concentration `C` using the quadratic-equation approach.
#
# For this educational example, use:
#
# ```text
# k > 0
# r ≥ 0
# C ≥ 0
# ```
#
# Your program should reject invalid inputs and identify the physically meaningful root.

# %% [markdown]
# ### Copilot Activity 6 – Input Validation
#
# Ask Copilot:
#
# > For a beginner Python program using r = kC², explain what input conditions I should validate for k and r if k is positive and concentration cannot be negative. Do not write the complete program.

# %%
# Activity 6
# Build the general reaction-rate calculator.
k = int(input("Enter the value of k: "))
r = int(input("Enter the value of r: "))    
if k > 0 and r >= 0:
    k = 5
    r = 10  
    a = k
    b = 0
    c = -r 

    determinant = b**2 - 4*a*c
    print("Determinant:", determinant)
    if determinant < 0:
     print("No real roots.")
    else:
     root1 = (-b + determinant**0.5) / (2*a)
     root2 = (-b - determinant**0.5) / (2*a)
     print("Roots:", root1, root2) 

     if  root1 >= 0:
        print(f"Physically meaningful root: {root1 :.4f}") 
        root = root1
     elif root2 >= 0:
        print(f"Physically meaningful root: {root2 :.4f}") 
        root = root2         
else :
    print("Invalid input. k must be greater than 0 and r must be greater than or equal to 0.")
# Out:
# Determinant: 200
# Roots: 1.4142135623730951 -1.4142135623730951
# Physically meaningful root: 1.4142

# %% [markdown]
# ## 10. Activity 7 – Compare Equilibrium and Reaction-Rate Problems
#
# Create a small comparison table in your notebook:
#
# | Problem | Unknown | Quadratic coefficients come from | Physical restriction |
# |---|---|---|---|
# | Equilibrium | `x` | Rearranged equilibrium expression | `0 ≤ x ≤ 1` |
# | Reaction rate | `C` | Rearranged rate expression | `C ≥ 0` |
#
# Then answer:
#
# **Why is solving the quadratic equation only one part of a chemical-engineering calculation?**

# %% [markdown]
# ### Copilot Activity 7 – Engineering Reasoning
#
# Ask Copilot:
#
# > Explain why a chemical engineer must apply physical constraints after solving an algebraic equation. Use equilibrium extent and concentration as examples. Do not write code.

# %% [markdown]
# ## 11. Activity 8 – Handle Special Cases
#
# Your solver should consider situations such as:
#
# - `a = 0` → the equation is not quadratic.
# - Negative discriminant → complex mathematical roots.
# - Invalid text input → numerical conversion error.
# - Equilibrium root outside `0 ≤ x ≤ 1` → reject that root as physically invalid for this simplified model.
# - Negative concentration → reject as physically invalid.
#
# Use appropriate `if/elif/else` logic and exception handling.

# %%
# Activity 8
# Improve your solver with validation and error handling.
try:
    choice = int(input("Enter 1 for equilibrium calculation or 2 for reaction rate calculation: "))
    print(f"Choice: {choice}")
    if choice == 1:
        kc = int(input("Enter the value of Kc: "))
        print("Kc =", kc)
        a = kc
        b = -(2*kc + 1)
        c = kc  
        print(f"Quadratic coefficients: a = {a}, b = {b}, c = {c}")    

        determinant = b**2 - 4*a*c
        print(f"Determinant: {determinant}")  

        if determinant < 0:
            print("No real roots.")
        else:   
            root1 = (-b + determinant**0.5) / (2*a)
            root2 = (-b - determinant**0.5) / (2*a)
            print(f"Roots: {root1 :.4f}, {root2 :.4f}")  

            if  0 <= root1 < 1.0:
                print(f"Physically meaningful root: {root1 :.4f}") 
                root = root1
            elif 0 <= root2 < 1.0:
                print(f"Physically meaningful root: {root2 :.4f}") 
                root = root2  

                A = 1 - root
                B = 1 - root
                C = root
                print(f"Equilibrium concentrations: A = {A :.4f}, B = {B :.4f}, C = {C :.4f}")
                print(f"Equilibrium constant: Kc = {kc :.4f}")
    elif choice == 2:       
        k = int(input("Enter the value of k: "))
        r = int(input("Enter the value of r: "))    
        if k > 0 and r >= 0:
            a = k
            b = 0
            c = -r 

            determinant = b**2 - 4*a*c
            print("Determinant:", determinant)
            if determinant < 0:
                print("No real roots.")
            else:
                root1 = (-b + determinant**0.5) / (2*a)
                root2 = (-b - determinant**0.5) / (2*a)
                print("Roots:", root1, root2) 

                if  root1 >= 0:
                    print(f"Physically meaningful root: {root1 :.4f}") 
                    root = root1
                elif root2 >= 0:
                    print(f"Physically meaningful root: {root2 :.4f}") 
                    root = root2         
        else :
            print("Invalid input. k must be greater than 0 and r must be greater than or equal to 0.")
    else:
        print("Invalid choice. Please enter 1 or 2.")
except ValueError:
    print("Invalid input. Please enter a valid integer.")
# Out:
# Choice: 1
# Kc = 3
# Quadratic coefficients: a = 3, b = -7, c = 3
# Determinant: 13
# Roots: 1.7676, 0.5657
# Physically meaningful root: 0.5657
# Equilibrium concentrations: A = 0.4343, B = 0.4343, C = 0.5657
# Equilibrium constant: Kc = 3.0000

# %% [markdown]
# ## 12. Copilot Debugging Challenge
#
# The following equilibrium program contains a logical error.
#
# Study it **before** asking Copilot.
#
# ```python
# Kc = 4
# a = Kc
# b = -(2*Kc + 1)
# c = Kc
#
# D = b**2 - 4*a*c
#
# x1 = (-b + D**0.5) / (2*a)
# x2 = (-b - D**0.5) / (2*a)
#
# print('x1 =', x1)
# print('x2 =', x2)
# ```
#
# ### Your task
#
# 1. Run the program.
# 2. Inspect both roots.
# 3. Decide which root is physically meaningful for `0 ≤ x ≤ 1`.
# 4. Ask Copilot:
#
# > My equilibrium quadratic solver gives two mathematical roots. Explain how I should programmatically check which root is physically meaningful when x must lie between 0 and 1. Do not rewrite the complete program.
#
# 5. Add the physical-root check yourself.

# %%
# Run the equilibrium example here.
Kc = 4
a = Kc
b = -(2*Kc + 1)
c = Kc

D = b**2 - 4*a*c

x1 = (-b + D**0.5) / (2*a)
x2 = (-b - D**0.5) / (2*a)

print('x1 =', x1)
print('x2 =', x2)

# %% [markdown]
# ### Explain the physical-root selection in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 13. Testing Your Programs
#
# ### Equilibrium solver
#
# Test several `Kc` values, for example:
#
# | Test | Kc | What to verify |
# |---|---:|---|
# | 1 | 0.5 | Valid physical root |
# | 2 | 1 | Valid physical root |
# | 3 | 4 | Valid physical root |
# | 4 | 10 | Valid physical root |
#
# For every case, verify that the selected equilibrium `x` lies between 0 and 1.
#
# ### Reaction-rate solver
#
# Test:
#
# | Test | k | r | What to verify |
# |---|---:|---:|---|
# | 1 | 2 | 8 | Positive concentration root |
# | 2 | 5 | 20 | Positive concentration root |
# | 3 | 10 | 0 | Zero concentration |
# | 4 | 0 | 5 | Invalid because k = 0 |
# | 5 | 2 | -1 | Invalid rate for this simplified model |

# %% [markdown]
# ## 14. Final Mini-Project – Chemical Quadratic Equation Solver
#
# Build one clean Python program that can solve quadratic equations arising from the two chemical-engineering examples in this practical.
#
# Provide a menu such as:
#
# ```text
# CHEMICAL ENGINEERING QUADRATIC SOLVER
# 1. Equilibrium calculation
# 2. Reaction-rate calculation
# ```
#
# ### Option 1 – Equilibrium
#
# The program should:
#
# 1. Accept `Kc`.
# 2. Generate the quadratic coefficients.
# 3. Calculate the discriminant.
# 4. Calculate both roots.
# 5. Select the root satisfying `0 ≤ x ≤ 1`.
# 6. Calculate equilibrium concentrations.
#
# ### Option 2 – Reaction Rate
#
# The program should:
#
# 1. Accept `k` and `r`.
# 2. Form the quadratic equation `kC² - r = 0`.
# 3. Calculate the roots.
# 4. Select the physically meaningful non-negative concentration.
#
# ### General requirements
#
# - Validate inputs.
# - Handle invalid cases gracefully.
# - Display the mathematical roots.
# - Clearly identify the physically meaningful solution.
# - Keep the program beginner-friendly.

# %%
# FINAL PROGRAM
# Chemical Engineering Quadratic Equation Solver
# Write your clean final solution here.

# %% [markdown]
# ## 15. Final Copilot Review
#
# Ask Copilot:
#
# > Review my chemical-engineering quadratic solver. Check the discriminant calculation, quadratic-formula implementation, equilibrium coefficient generation, reaction-rate coefficient generation, input validation and physical-root selection. Do not rewrite my program; identify possible issues and explain them.
#
# Make corrections only after you understand the feedback.

# %% [markdown]
# ## 16. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. How can a chemical equilibrium expression lead to a quadratic equation?
# 2. What does `x` represent in the equilibrium example?
# 3. Why must equilibrium `x` satisfy a physical range?
# 4. How can a reaction-rate expression such as `r = kC²` be converted into a quadratic equation?
# 5. What does the discriminant tell you?
# 6. Why can a mathematical root be rejected in an engineering problem?
# 7. What did Copilot help you understand or debug?
# 8. Which part of the program did you write yourself after receiving a Copilot hint?
# 9. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 17. Submission Checklist
#
# - [ ] I identified quadratic coefficients correctly.
# - [ ] I calculated the discriminant.
# - [ ] I solved a simplified equilibrium expression using a quadratic equation.
# - [ ] I solved a simplified reaction-rate expression using a quadratic equation.
# - [ ] I handled real and complex mathematical roots appropriately.
# - [ ] I applied physical restrictions to select meaningful roots.
# - [ ] I validated user input.
# - [ ] I tested different equilibrium and reaction-rate values.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 18. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Correct identification of quadratic coefficients | 1 |
# | Discriminant and quadratic-root calculation | 2 |
# | Equilibrium application | 2 |
# | Reaction-rate application | 1 |
# | Physical-root selection | 1 |
# | Input/error handling and testing | 1 |
# | Copilot usage and explanation | 1 |
# | Student's ability to explain/modify the program | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, give a new `Kc` or a new `k, r` pair and ask the student to predict the physically meaningful root before running the program. Ask why the other mathematical root is rejected.
